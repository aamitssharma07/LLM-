# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install -qqq -r "/content/drive/My Drive/LLMProjects/requirements.txt"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 2.4 MB/s eta 0:00:00

# %%
# !pip install git+https://github.com/openai/whisper.git #install whisper getting from github
# !sudo apt update && sudo apt install ffmpeg #ffmpeg allows us to work with audio and video files
# !pip install pytube
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-1odakirw
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-1odakirw
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
from pytube import YouTube

def download_youtube_audio(video_url):
    yt = YouTube(video_url)
    stream = yt.streams.filter(only_audio=True).first()
    audio_file_path = yt.title + ".mp3"  # Output audio file path

    stream.download(filename=audio_file_path)

    return audio_file_path

# %%
# Main code flow
video_url = "https://www.youtube.com/watch?v=YphL3Whh5B0"
audio_file_path = download_youtube_audio(video_url)
print(audio_file_path)
# Out:
# Cricket World Cup 2011 Final: India v Sri Lanka | Match Highlights.mp3

# %%
 # run whisper asr
#!whisper "/content/Pharmacology - IMMUNOSUPPRESSANTS (MADE EASY).mp3" --model medium.en
# !whisper "Cricket World Cup 2011 Final: India v Sri Lanka | Match Highlights.mp3" --model medium.en --output_format txt
# Out:
# [00:00.000 --> 00:07.120]  this is where you felt something's going to give he's been itching to get on strike first boundary
# [00:07.120 --> 00:13.760]  of the final cuts and cuts hard that's typical darshan
# [00:17.040 --> 00:23.280]  edge and taken a good catch at first slip pace and bounce and this time movement two
# [00:23.280 --> 00:27.440]  for zayikhan gets the outside edge and they've claimed upal taranga
# [00:31.680 --> 00:35.200]  lovely shot the sangakara cover drive
# [00:38.000 --> 00:42.000]  and so sangakara has to go over the field if they're stopping them on the ground take the
# [00:42.000 --> 00:49.760]  aerial route another nice drive down the ground save your legs four more back-to-back boundaries
# [00:49.840 --> 00:58.160]  has he gone has he been bowled around his legs i think so the indians celebrate
# [00:58.960 --> 01:03.200]  it's come off some part of his body parvajan takes the wicket
# ...

# %% [markdown]
# ##Generate Questions and Answers using LLM (Groq)

# %%
from groq import Groq
import os

# Read and set the environment variable from the .bashrc file
with open('/content/drive/My Drive/LLMProjects/.bashrc') as file:
       for line in file:
                if line.startswith('export '):
                      var, value = line[len('export '):].strip().split('=')
                      os.environ[var] = value

# %%
client2 = Groq()

def get_completion(prompt, model="llama3-8b-8192"):
    messages = [{"role": "user", "content": prompt}]
    response = client2.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
text = """
[00:00.000 --> 00:07.120]  this is where you felt something's going to give he's been itching to get on strike first boundary
[00:07.120 --> 00:13.760]  of the final cuts and cuts hard that's typical darshan
[00:17.040 --> 00:23.280]  edge and taken a good catch at first slip pace and bounce and this time movement two
[00:23.280 --> 00:27.440]  for zayikhan gets the outside edge and they've claimed upal taranga
[00:31.680 --> 00:35.200]  lovely shot the sangakara cover drive
[00:38.000 --> 00:42.000]  and so sangakara has to go over the field if they're stopping them on the ground take the
[00:42.000 --> 00:49.760]  aerial route another nice drive down the ground save your legs four more back-to-back boundaries
[00:49.840 --> 00:58.160]  has he gone has he been bowled around his legs i think so the indians celebrate
[00:58.960 --> 01:03.200]  it's come off some part of his body parvajan takes the wicket
[01:06.400 --> 01:09.120]  let's hit in the gap and that would go all the way for four
[01:13.840 --> 01:18.000]  the shot delivery pulled away in the gap would get a boundary from mahala
[01:20.000 --> 01:27.920]  does play that shot well now that's a a classy shot from mahila jay
[01:27.920 --> 01:38.160]  brilliant placement excellent footwork now this is high quality batting from both these players
[07:03.440 --> 07:05.760]  and the ball crashes onto middle stump
[07:07.760 --> 07:12.480]  pulled away in grand fashion and a nice way to open the account
[07:13.440 --> 07:16.640]  that's a fierce square cut over the boundary
[07:20.000 --> 07:22.640]  that's it very hard through the offside
[07:25.280 --> 07:26.640]  on side four more
[07:31.680 --> 07:34.640]  four more he's doing it easily
[07:35.280 --> 07:43.920]  finishes off in style a magnificent strike into the crowd india lift the world cup after 28 years
[07:43.920 --> 07:51.200]  the bodies start in the dressing room and it's an indian captain who's been absolutely magnificent
[07:51.200 --> 07:59.280]  in the night of the final well there's the man section ten duker he's been
"""

prompt = f"""
The following text is a transcription of the cricket commentary from the 2011 Cricket World Cup Final between India and Sri Lanka.
I need you to create 5 engaging, informative, and interactive questions, along with their respective answers, based on the content of this transcription.
These questions should be directly relevant to the events and players mentioned in the transcription and should help in understanding the critical moments
and highlights of the match. The aim is to create questions that would be interesting for someone who wants to learn more about the match's key moments,
strategies, and outcomes.

Please ensure that the questions cover various aspects of the match, such as key players' performances, significant events, and turning points.
Each question should be followed by a concise and accurate answer derived from the transcription.

Output only the 5 questions and their corresponding answers in plain text, without any additional text, formatting, or labels. Do not include any introductory text or headers.

Here is the transcription:

```{text}```
"""



response1 = get_completion(prompt)
print(response1)
# Out:
# Here are the 5 questions and their corresponding answers:
#
# Q1: Who took a good catch at first slip to dismiss Upul Tharanga?
# Answer: Parvajan took the wicket.
#
# Q2: Which Indian batsman scored a half-century in the match?
# Answer: Mahela Jayawardene scored 50 off 49 balls.
#
# Q3: Who bowled a beauty of a slower delivery to dismiss Mahela Jayawardene?
# Answer: Zahir Khan bowled the slower delivery.
#
# Q4: Who was the Indian batsman who was given out by the umpire, but later reviewed and was found to be not out?
# Answer: Virender Sehwag was given out, but the review showed that he was not out.
#
# Q5: Who was the Indian batsman who scored a magnificent 50 in the match?
# Answer: Gautam Gambhir scored 50 off 39 balls.

# %% [markdown]
# ## Code to conevrt Text into Speech

# %%
# !pip install gtts

# %%
from gtts import gTTS
import os

# Create a gTTS object
tts = gTTS(text=response1, lang='en')

# Save the audio file
tts.save("commentary_summary.mp3")

# Optionally, play the audio file (requires an audio player installed)
os.system("start commentary_summary.mp3")  # For Windows
# os.system("mpg321 commentary_summary.mp3")  # For Linux
# Out:
# 32512

# %% [markdown]
# ##Play the Audio File

# %%
from IPython.display import Audio, display

# Display the audio player
display(Audio("commentary_summary.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Generate Questions and Answers using LLM (OpenAI)

# %%
import openai
import os

# Path to your .bashrc file
bashrc_path = '/content/drive/MyDrive/LLMProjects/.bashrc'

# Read the .bashrc file and extract the API key
with open(bashrc_path, 'r') as file:
    lines = file.readlines()
    for line in lines:
        if line.startswith('export OPENAI_API_KEY='):
            openai_api_key = line.split('=')[1].strip().strip('"')

# Set the OpenAI API key
os.environ['OPENAI_API_KEY'] = openai_api_key

# Retrieve the OpenAI API key from the environment variables
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key is None:
    raise ValueError("OpenAI API key not found. Please set it in the environment variables.")

# Set the OpenAI API key
openai.api_key = openai_api_key

# %%
client = openai.OpenAI()

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
[05:58.160 --> 06:01.760]  and he's going to get the ball back and he's going to get the ball back
[06:03.760 --> 06:10.720]  dioshan balling a full coley getting a leading edge and what a catch that is he's a brilliant fielder
[06:15.600 --> 06:20.720]  back foot this time powerful shot into the off side oh yes it's powerful
[06:20.960 --> 06:23.920]  into the off side and we've talked powerful there's another
[06:26.960 --> 06:31.360]  smashed away absolutely heaved into the lakeside
[06:35.200 --> 06:36.720]  that's one of his favorite shots
[06:40.880 --> 06:46.560]  great shot and that brings up the 50 the first 50 for my interesting pony in this tournament
[06:46.560 --> 06:52.400]  and no celebration he knows there's a bigger mission on here 204 for three
[06:58.240 --> 07:02.800]  a needless shot coming down the track looking to head through the offside gets an inside edge
[07:03.440 --> 07:05.760]  and the ball crashes onto middle stump
[07:07.760 --> 07:12.480]  pulled away in grand fashion and a nice way to open the account
[07:13.440 --> 07:16.640]  that's a fierce square cut over the boundary
[07:20.000 --> 07:22.640]  that's it very hard through the offside
[07:25.280 --> 07:26.640]  on side four more
[07:31.680 --> 07:34.640]  four more he's doing it easily
[07:35.280 --> 07:43.920]  finishes off in style a magnificent strike into the crowd india lift the world cup after 28 years
[07:43.920 --> 07:51.200]  the bodies start in the dressing room and it's an indian captain who's been absolutely magnificent
[07:51.200 --> 07:59.280]  in the night of the final well there's the man section ten duker he's been
"""

prompt = f"""
The following text is a transcription of the cricket commentary from the 2011 Cricket World Cup Final between India and Sri Lanka.
I need you to create 5 engaging, informative, and interactive questions, along with their respective answers, based on the content of this transcription.
These questions should be directly relevant to the events and players mentioned in the transcription and should help in understanding the critical moments
and highlights of the match. The aim is to create questions that would be interesting for someone who wants to learn more about the match's key moments,
strategies, and outcomes.

Please ensure that the questions cover various aspects of the match, such as key players' performances, significant events, and turning points.
Each question should be followed by a concise and accurate answer derived from the transcription.

Output only the 5 questions and their corresponding answers in plain text, without any additional text, formatting, or labels. Do not include any introductory text or headers.

Here is the transcription:

```{text}```
"""



response = get_completion(prompt)
print(response)
# Out:
# 1. Who took a crucial catch at first slip to dismiss Upul Tharanga in the 2011 Cricket World Cup Final?
#    - Answer: A good catch at first slip was taken by the fielder to dismiss Upul Tharanga.
#
# 2. How did Mahela Jayawardene reach his 50 in the final, and in how many balls?
#    - Answer: Mahela Jayawardene reached his 50 in the final by scoring it off 49 balls.
#
# 3. Which bowler delivered a slower ball that resulted in a wicket during the final?
#    - Answer: A slower delivery bowled by Zahir resulted in a wicket during the final.
#
# 4. Who took a good low catch to dismiss a key Indian batsman in the final?
#    - Answer: Kumar Sangakkara took a good low catch to dismiss a key Indian batsman in the final.
#
# 5. How did the 2011 Cricket World Cup Final end, and who emerged as the champions?
#    - Answer: The final ended with a magnificent strike into the crowd, and India emerged as the champions after 28 years.

# %%
# !pip install gtts

# %% [markdown]
# ## Code to conevrt Text into Speech

# %%
from gtts import gTTS
import os

# Create a gTTS object
tts = gTTS(text=response, lang='en')

# Save the audio file
tts.save("commentary_summary2.mp3")

# Optionally, play the audio file (requires an audio player installed)
os.system("start commentary_summary2.mp3")  # For Windows
# os.system("mpg321 commentary_summary2.mp3")  # For Linux
# Out:
# 32512

# %%
from IPython.display import Audio, display

# Display the audio player
display(Audio("commentary_summary2.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
